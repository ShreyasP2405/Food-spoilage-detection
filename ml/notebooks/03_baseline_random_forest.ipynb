# %% [markdown]
# # 03 - Random Forest Baseline
#
# Honest non-temporal baseline. Saves `rf_baseline.joblib`, `scaler.joblib`, and metrics in `metadata.json`.

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd().resolve().parents[1]
sys.path.insert(0, str(ROOT))
from ml.src.train_rf import main
main()
