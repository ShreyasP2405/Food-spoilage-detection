# %% [markdown]
# # 04 - LSTM Training (main model)
#
# Sliding-window LSTM over the last 24 hours of readings (48 timesteps x 7 features). Saves `lstm_model.keras` and updates `metadata.json`.

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd().resolve().parents[1]
sys.path.insert(0, str(ROOT))
from ml.src.train_lstm import main
main()
